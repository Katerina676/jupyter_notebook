# %%
import pandas as pd
import numpy as np

# %%
df = pd.DataFrame({
    'country': ['Kazahstan', 'Russia', 'Belarus', 'Ukraine'],
    'population': [17.04, 143.5, 9.5, 45.5],
     'square': [2724902, 17125191, 207600, 603550]
})
df
# Out:
#      country  population    square
# 0  Kazahstan       17.04   2724902
# 1     Russia      143.50  17125191
# 2    Belarus        9.50    207600
# 3    Ukraine       45.50    603550

# %%
df.population
# Out:
# 0     17.04
# 1    143.50
# 2      9.50
# 3     45.50
# Name: population, dtype: float64

# %%
type(df.population)
# Out:
# pandas.core.series.Series

# %%
df.index = ['KZ', 'RU', 'BY', 'UA']
df
# Out:
#       country  population    square
# KZ  Kazahstan       17.04   2724902
# RU     Russia      143.50  17125191
# BY    Belarus        9.50    207600
# UA    Ukraine       45.50    603550

# %%
data = pd.read_csv('Downloads/meteorite-landings.csv')

# %%
data.tail()
# Out:
#              name     id nametype              recclass    mass   fall  \
# 45711  Zillah 002  31356    Valid               Eucrite   172.0  Found
# 45712      Zinder  30409    Valid  Pallasite, ungrouped    46.0  Found
# 45713        Zlin  30410    Valid                    H4     3.3  Found
# 45714   Zubkovsky  31357    Valid                    L6  2167.0  Found
# 45715  Zulu Queen  30414    Valid                  L3.7   200.0  Found
#
#          year    reclat    reclong               GeoLocation
# 45711  1990.0  29.03700   17.01850    (29.037000, 17.018500)
# 45712  1999.0  13.78333    8.96667     (13.783330, 8.966670)
# 45713  1939.0  49.25000   17.66667    (49.250000, 17.666670)
# 45714  2003.0  49.78917   41.50460    (49.789170, 41.504600)
# 45715  1976.0  33.98333 -115.68333  (33.983330, -115.683330)

# %%
data.head()
# Out:
#        name   id nametype     recclass      mass  fall    year    reclat  \
# 0    Aachen    1    Valid           L5      21.0  Fell  1880.0  50.77500
# 1    Aarhus    2    Valid           H6     720.0  Fell  1951.0  56.18333
# 2      Abee    6    Valid          EH4  107000.0  Fell  1952.0  54.21667
# 3  Acapulco   10    Valid  Acapulcoite    1914.0  Fell  1976.0  16.88333
# 4   Achiras  370    Valid           L6     780.0  Fell  1902.0 -33.16667
#
#      reclong               GeoLocation
# 0    6.08333     (50.775000, 6.083330)
# 1   10.23333    (56.183330, 10.233330)
# 2 -113.00000  (54.216670, -113.000000)
# 3  -99.90000   (16.883330, -99.900000)
# 4  -64.95000  (-33.166670, -64.950000)

# %%
#c_size = 10000

#for gm_chunk in pd.read_csv('Downloads/', chunksize=c_size):
#print(gm_chunk.shape)


#читать данные по частям

# %%
df.loc['KZ']
# Out:
# country       Kazahstan
# population        17.04
# square          2724902
# Name: KZ, dtype: object

# %%
df.iloc[0]
# Out:
# country       Kazahstan
# population        17.04
# square          2724902
# Name: KZ, dtype: object

# %%
df.loc[['KZ', 'RU'], 'population']
# Out:
# KZ     17.04
# RU    143.50
# Name: population, dtype: float64

# %%
# в iloc и loc сначало строки потом столбцы

# %%
df.iloc[[0, 1],[1]]
# Out:
#     population
# KZ       17.04
# RU      143.50

# %%
df[df.population > 10][['country', 'square']]
# Out:
#       country    square
# KZ  Kazahstan   2724902
# RU     Russia  17125191
# UA    Ukraine    603550

# %%
df[(df.square > 70000) & (df.country == 'Russia')][['country', 'square']]
# Out:
#    country    square
# RU  Russia  17125191

# %%
filters = (df.country == 'Russia')
df[filters]
# Out:
#    country  population    square
# RU  Russia       143.5  17125191

# %%
df['destiny'] = df['population'] / df['square'] * 1000000
df
# Out:
#       country  population    square    destiny
# KZ  Kazahstan       17.04   2724902   6.253436
# RU     Russia      143.50  17125191   8.379469
# BY    Belarus        9.50    207600  45.761079
# UA    Ukraine       45.50    603550  75.387292

# %%
df.drop(['destiny'], axis=1)
# Out:
#       country  population    square
# KZ  Kazahstan       17.04   2724902
# RU     Russia      143.50  17125191
# BY    Belarus        9.50    207600
# UA    Ukraine       45.50    603550

# %%
df = df.drop(['destiny'], axis=1)        #убрать дроп. если Inplace=true то сразу запишется
df
# Out:
#       country  population    square
# KZ  Kazahstan       17.04   2724902
# RU     Russia      143.50  17125191
# BY    Belarus        9.50    207600
# UA    Ukraine       45.50    603550

# %%
df = df.rename(columns={'Country code': 'country_code'})
df
# Out:
#       country  population    square
# KZ  Kazahstan       17.04   2724902
# RU     Russia      143.50  17125191
# BY    Belarus        9.50    207600
# UA    Ukraine       45.50    603550

# %%
df.nlargest(3,'population')    #выстраивает топ 3
# Out:
#       country  population    square
# RU     Russia      143.50  17125191
# UA    Ukraine       45.50    603550
# KZ  Kazahstan       17.04   2724902

# %%
df.nsmallest(3,'square')
# Out:
#       country  population   square
# BY    Belarus        9.50   207600
# UA    Ukraine       45.50   603550
# KZ  Kazahstan       17.04  2724902

# %%
data.head()
# Out:
#        name   id nametype     recclass      mass  fall    year    reclat  \
# 0    Aachen    1    Valid           L5      21.0  Fell  1880.0  50.77500
# 1    Aarhus    2    Valid           H6     720.0  Fell  1951.0  56.18333
# 2      Abee    6    Valid          EH4  107000.0  Fell  1952.0  54.21667
# 3  Acapulco   10    Valid  Acapulcoite    1914.0  Fell  1976.0  16.88333
# 4   Achiras  370    Valid           L6     780.0  Fell  1902.0 -33.16667
#
#      reclong               GeoLocation
# 0    6.08333     (50.775000, 6.083330)
# 1   10.23333    (56.183330, 10.233330)
# 2 -113.00000  (54.216670, -113.000000)
# 3  -99.90000   (16.883330, -99.900000)
# 4  -64.95000  (-33.166670, -64.950000)

# %%
pd.set_option('display.max_columns',100)
pd.set_option('display.max_rows',100)

# %%
pd.set_option('display.precision',3)

# %%
data.head(90)
# Out:
#                       name     id nametype         recclass       mass   fall  \
# 0                   Aachen      1    Valid               L5  2.100e+01   Fell
# 1                   Aarhus      2    Valid               H6  7.200e+02   Fell
# 2                     Abee      6    Valid              EH4  1.070e+05   Fell
# 3                 Acapulco     10    Valid      Acapulcoite  1.914e+03   Fell
# 4                  Achiras    370    Valid               L6  7.800e+02   Fell
# 5                 Adhi Kot    379    Valid              EH4  4.239e+03   Fell
# 6      Adzhi-Bogdo (stone)    390    Valid            LL3-6  9.100e+02   Fell
# 7                     Agen    392    Valid               H5  3.000e+04   Fell
# 8                   Aguada    398    Valid               L6  1.620e+03   Fell
# 9            Aguila Blanca    417    Valid                L  1.440e+03   Fell
# 10        Aioun el Atrouss    423    Valid     Diogenite-pm  1.000e+03   Fell
# ...

# %%
data.shape
# Out:
# (45716, 10)

# %%
data.shape[0]
# Out:
# 45716

# %%
data.columns
# Out:
# Index(['name', 'id', 'nametype', 'recclass', 'mass', 'fall', 'year', 'reclat',
#        'reclong', 'GeoLocation'],
#       dtype='object')

# %%
data.describe()
# Out:
#               id       mass       year     reclat    reclong
# count  45716.000  4.558e+04  45428.000  38401.000  38401.000
# mean   26889.735  1.328e+04   1991.772    -39.123     61.074
# std    16860.683  5.750e+05     27.181     46.379     80.647
# min        1.000  0.000e+00    301.000    -87.367   -165.433
# 25%    12688.750  7.200e+00   1987.000    -76.714      0.000
# 50%    24261.500  3.260e+01   1998.000    -71.500     35.667
# 75%    40656.750  2.026e+02   2003.000      0.000    157.167
# max    57458.000  6.000e+07   2501.000     81.167    354.473

# %%
data.describe(include=['object'])
# Out:
#                 name nametype recclass   fall           GeoLocation
# count          45716    45716    45716  45716                 38401
# unique         45716        2      466      2                 17100
# top     Asuka 880688    Valid       L6  Found  (0.000000, 0.000000)
# freq               1    45641     8285  44609                  6214

# %%
data.recclass.value_counts()[:5]
# Out:
# L6    8285
# H5    7142
# L5    4796
# H6    4528
# H4    4211
# Name: recclass, dtype: int64

# %%
print(data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45716 entries, 0 to 45715
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   name         45716 non-null  object
#  1   id           45716 non-null  int64
#  2   nametype     45716 non-null  object
#  3   recclass     45716 non-null  object
#  4   mass         45585 non-null  float64
#  5   fall         45716 non-null  object
#  6   year         45428 non-null  float64
#  7   reclat       38401 non-null  float64
#  8   reclong      38401 non-null  float64
#  9   GeoLocation  38401 non-null  object
# dtypes: float64(4), int64(1), object(5)
# memory usage: 3.5+ MB
# None

# %%
for dtype in ['float', 'int', 'object']:
    selected_dtype = data.select_dtypes(include=[dtype])
    mean_usage_b = selected_dtype.memory_usage(deep=True).mean()
    mean_usage_mb = mean_usage_b / 1024 ** 2
    print("Average memory usage for {} columns: {:03.2f} MB".format(dtype,mean_usage_mb))
# Out:
# Average memory usage for float columns: 0.28 MB
# Average memory usage for int columns: 0.00 MB
# Average memory usage for object columns: 2.41 MB

# %%
data['mass'] = data['mass'].astype('float32')

# %%
print(data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45716 entries, 0 to 45715
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   name         45716 non-null  object
#  1   id           45716 non-null  int64
#  2   nametype     45716 non-null  object
#  3   recclass     45716 non-null  object
#  4   mass         45585 non-null  float32
#  5   fall         45716 non-null  object
#  6   year         45428 non-null  float64
#  7   reclat       38401 non-null  float64
#  8   reclong      38401 non-null  float64
#  9   GeoLocation  38401 non-null  object
# dtypes: float32(1), float64(3), int64(1), object(5)
# memory usage: 3.3+ MB
# None

# %%
[(col, data[col].nunique()) for col in data.columns]
# Out:
# [('name', 45716),
#  ('id', 45716),
#  ('nametype', 2),
#  ('recclass', 466),
#  ('mass', 12576),
#  ('fall', 2),
#  ('year', 268),
#  ('reclat', 12738),
#  ('reclong', 14640),
#  ('GeoLocation', 17100)]

# %%
unique_counts = pd.DataFrame.from_records([(col, data[col].nunique()) for col in data.columns],
                                         columns = ['Column_name', 'Num_Unique']).sort_values(by=['Num_Unique'])
unique_counts
# Out:
#    Column_name  Num_Unique
# 2     nametype           2
# 5         fall           2
# 6         year         268
# 3     recclass         466
# 4         mass       12576
# 7       reclat       12738
# 8      reclong       14640
# 9  GeoLocation       17100
# 0         name       45716
# 1           id       45716

# %%
data_with_cat = data.copy()

# %%
data_with_cat['recclass'] = data_with_cat['recclass'].astype('category')

# %%
print(data_with_cat.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45716 entries, 0 to 45715
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   name         45716 non-null  object
#  1   id           45716 non-null  int64
#  2   nametype     45716 non-null  object
#  3   recclass     45716 non-null  category
#  4   mass         45585 non-null  float32
#  5   fall         45716 non-null  object
#  6   year         45428 non-null  float64
#  7   reclat       38401 non-null  float64
#  8   reclong      38401 non-null  float64
#  9   GeoLocation  38401 non-null  object
# dtypes: category(1), float32(1), float64(3), int64(1), object(4)
# memory usage: 3.1+ MB
# None

# %%
# %%timeit
data_with_cat.groupby('recclass')['mass'].mean().to_frame()
# Out:
# 1.52 ms ± 254 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)

# %%
# %%timeit
data.groupby('recclass')['mass'].mean().to_frame()
# Out:
# 4.91 ms ± 370 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %%
data.sort_values(by=['recclass', 'mass'], ascending=[True, False]).head(2)
# Out:
#                         name     id nametype     recclass    mass   fall  \
# 27673  Northwest Africa 2656  32485    Valid  Acapulcoite  7500.0  Found
# 30353   Northwest Africa 725  17807    Valid  Acapulcoite  3824.0  Found
#
#          year  reclat  reclong             GeoLocation
# 27673  2003.0     NaN      NaN                     NaN
# 30353     NaN    30.6    -5.05  (30.600000, -5.050000)

# %%
data.loc[0:5, :]
# Out:
#        name   id nametype     recclass      mass  fall    year  reclat  \
# 0    Aachen    1    Valid           L5      21.0  Fell  1880.0  50.775
# 1    Aarhus    2    Valid           H6     720.0  Fell  1951.0  56.183
# 2      Abee    6    Valid          EH4  107000.0  Fell  1952.0  54.217
# 3  Acapulco   10    Valid  Acapulcoite    1914.0  Fell  1976.0  16.883
# 4   Achiras  370    Valid           L6     780.0  Fell  1902.0 -33.167
# 5  Adhi Kot  379    Valid          EH4    4239.0  Fell  1919.0  32.100
#
#    reclong               GeoLocation
# 0    6.083     (50.775000, 6.083330)
# 1   10.233    (56.183330, 10.233330)
# 2 -113.000  (54.216670, -113.000000)
# 3  -99.900   (16.883330, -99.900000)
# 4  -64.950  (-33.166670, -64.950000)
# 5   71.800    (32.100000, 71.800000)

# %%
data[data['name'] == 'Abee']['mass'].mean()
# Out:
# 107000.0

# %%
data.fall.value_counts()
# Out:
# Found    44609
# Fell      1107
# Name: fall, dtype: int64

# %%
data[['mass', 'id']].apply(np.max)
# Out:
# mass    6.000e+07
# id      5.746e+04
# dtype: float64

# %%
d = {'Found' : 1, 'Fell' : 0}
data['status'] = data['fall'].map(d)
data.tail(2)
# Out:
#              name     id nametype recclass    mass   fall    year  reclat  \
# 45714   Zubkovsky  31357    Valid       L6  2167.0  Found  2003.0  49.789
# 45715  Zulu Queen  30414    Valid     L3.7   200.0  Found  1976.0  33.983
#
#        reclong               GeoLocation  status
# 45714   41.505    (49.789170, 41.504600)       1
# 45715 -115.683  (33.983330, -115.683330)       1

# %%
data.groupby(by = 'fall')['mass'].max()
# Out:
# fall
# Fell     2.300e+07
# Found    6.000e+07
# Name: mass, dtype: float32

# %%
data.groupby(by = 'fall')['mass'].agg([np.mean, np.std, np.min, np.max])
# Out:
#             mean         std  amin       amax
# fall
# Fell   47070.715  717067.125   0.1  2.300e+07
# Found  12461.923  571105.750   0.0  6.000e+07

# %%
pd.crosstab(data['fall'], data['nametype'])
# Out:
# nametype  Relict  Valid
# fall
# Fell           0   1107
# Found         75  44534

# %%
pd.crosstab(data['fall'], data['nametype'], normalize=True)
# Out:
# nametype  Relict  Valid
# fall
# Fell       0.000  0.024
# Found      0.002  0.974

# %%
raw_data = {
    'subject_id': ['1','2','3','4','5'],
    'first_name':['Alex', 'Amy', 'Allen', 'Alice', 'Ayoung'],
    'last_name':['Andersson', 'Ackerman', 'Ali', 'Aoni', 'Atiches']}
df_a = pd.DataFrame(raw_data, columns = ['subject_id', 'first_name', 'last_name'])
df_a.index = [0,1,2,3,4]
df_a
# Out:
#   subject_id first_name  last_name
# 0          1       Alex  Andersson
# 1          2        Amy   Ackerman
# 2          3      Allen        Ali
# 3          4      Alice       Aoni
# 4          5     Ayoung    Atiches

# %%
raw_data = {
    'subject_id': ['4','5','6','7','8'],
    'first_name':['Billy', 'Brain', 'Bran', 'Bruce', 'Betty'],
    'last_name':['Bonder', 'Black', 'Balwner', 'Brice', 'Btisan']}
df_b = pd.DataFrame(raw_data, columns = ['subject_id', 'first_name', 'last_name'])
df_b.index = [2,3,4,5,6]
df_b
# Out:
#   subject_id first_name last_name
# 2          4      Billy    Bonder
# 3          5      Brain     Black
# 4          6       Bran   Balwner
# 5          7      Bruce     Brice
# 6          8      Betty    Btisan

# %%
raw_data = {
    'subject_id': ['1','2','3','4','5'],
    'test_id':['56', '51', '89', '11', '2']}
df_n = pd.DataFrame(raw_data, columns = ['subject_id', 'test_id'])
df_n
# Out:
#   subject_id test_id
# 0          1      56
# 1          2      51
# 2          3      89
# 3          4      11
# 4          5       2

# %%
df_new = pd.concat([df_a, df_b])
df_new
# Out:
#   subject_id first_name  last_name
# 0          1       Alex  Andersson
# 1          2        Amy   Ackerman
# 2          3      Allen        Ali
# 3          4      Alice       Aoni
# 4          5     Ayoung    Atiches
# 2          4      Billy     Bonder
# 3          5      Brain      Black
# 4          6       Bran    Balwner
# 5          7      Bruce      Brice
# 6          8      Betty     Btisan

# %%
df_new = pd.concat([df_a, df_b], axis=1)
df_new
# Out:
#   subject_id first_name  last_name subject_id first_name last_name
# 0          1       Alex  Andersson        NaN        NaN       NaN
# 1          2        Amy   Ackerman        NaN        NaN       NaN
# 2          3      Allen        Ali          4      Billy    Bonder
# 3          4      Alice       Aoni          5      Brain     Black
# 4          5     Ayoung    Atiches          6       Bran   Balwner
# 5        NaN        NaN        NaN          7      Bruce     Brice
# 6        NaN        NaN        NaN          8      Betty    Btisan

# %%
df_new = pd.concat([df_a, df_b], axis=1, join='inner')
df_new
# Out:
#   subject_id first_name last_name subject_id first_name last_name
# 2          3      Allen       Ali          4      Billy    Bonder
# 3          4      Alice      Aoni          5      Brain     Black
# 4          5     Ayoung   Atiches          6       Bran   Balwner

# %%
df_a.append(df_b)
# Out:
#   subject_id first_name  last_name
# 0          1       Alex  Andersson
# 1          2        Amy   Ackerman
# 2          3      Allen        Ali
# 3          4      Alice       Aoni
# 4          5     Ayoung    Atiches
# 2          4      Billy     Bonder
# 3          5      Brain      Black
# 4          6       Bran    Balwner
# 5          7      Bruce      Brice
# 6          8      Betty     Btisan

# %%
df_a.join(df_b,rsuffix='_right_table',how='left')
# Out:
#   subject_id first_name  last_name subject_id_right_table  \
# 0          1       Alex  Andersson                    NaN
# 1          2        Amy   Ackerman                    NaN
# 2          3      Allen        Ali                      4
# 3          4      Alice       Aoni                      5
# 4          5     Ayoung    Atiches                      6
#
#   first_name_right_table last_name_right_table
# 0                    NaN                   NaN
# 1                    NaN                   NaN
# 2                  Billy                Bonder
# 3                  Brain                 Black
# 4                   Bran               Balwner

# %%
pd.merge(df_a, df_b, on='subject_id', how='left')
# Out:
#   subject_id first_name_x last_name_x first_name_y last_name_y
# 0          1         Alex   Andersson          NaN         NaN
# 1          2          Amy    Ackerman          NaN         NaN
# 2          3        Allen         Ali          NaN         NaN
# 3          4        Alice        Aoni        Billy      Bonder
# 4          5       Ayoung     Atiches        Brain       Black

# %%
pd.merge(df_a, df_b, on='subject_id', how='right')
# Out:
#   subject_id first_name_x last_name_x first_name_y last_name_y
# 0          4        Alice        Aoni        Billy      Bonder
# 1          5       Ayoung     Atiches        Brain       Black
# 2          6          NaN         NaN         Bran     Balwner
# 3          7          NaN         NaN        Bruce       Brice
# 4          8          NaN         NaN        Betty      Btisan

# %%
pd.merge(df_a, df_b, right_index=True, left_index=True)
# Out:
#   subject_id_x first_name_x last_name_x subject_id_y first_name_y last_name_y
# 2            3        Allen         Ali            4        Billy      Bonder
# 3            4        Alice        Aoni            5        Brain       Black
# 4            5       Ayoung     Atiches            6         Bran     Balwner
